# %%
import pandas as pd

# %%
df = pd.read_csv("all-resep-makanan.csv")

# %%
df
# Out:
#                                    Title  \
# 0                       Ayam Woku Manado
# 1               Ayam goreng tulang lunak
# 2                       Ayam cabai kawin
# 3                            Ayam Geprek
# 4                            Minyak Ayam
# ...                                  ...
# 13662                 Udang saus mentega
# 13663                 Jipang tumis udang
# 13664                  Tumis Udang Tempe
# 13665  Tumis kacang panjang terong udang
# 13666                  Siomay Udang Ayam
#
#                                              Ingredients  \
# 0      1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1      1 kg ayam (dipotong sesuai selera jangan kecil...
# 2      1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3      250 gr daging ayam (saya pakai fillet)--Secuku...
# 4      400 gr kulit ayam & lemaknya--8 siung bawang p...
# ...                                                  ...
# 13662  1 kg udang segar--1 buah bawang bombay kecil--...
# ...

# %%
df = df.drop('URL', axis=1)

# %%
df = df.drop('Steps', axis=1)

# %%
df
# Out:
#                                    Title  \
# 0                       Ayam Woku Manado
# 1               Ayam goreng tulang lunak
# 2                       Ayam cabai kawin
# 3                            Ayam Geprek
# 4                            Minyak Ayam
# ...                                  ...
# 13662                 Udang saus mentega
# 13663                 Jipang tumis udang
# 13664                  Tumis Udang Tempe
# 13665  Tumis kacang panjang terong udang
# 13666                  Siomay Udang Ayam
#
#                                              Ingredients  Loves  \
# 0      1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...      1
# 1      1 kg ayam (dipotong sesuai selera jangan kecil...      1
# 2      1/4 kg ayam--3 buah cabai hijau besar--7 buah ...      2
# 3      250 gr daging ayam (saya pakai fillet)--Secuku...     10
# 4      400 gr kulit ayam & lemaknya--8 siung bawang p...      4
# ...                                                  ...    ...
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# Function to clean text
def clean_ingredients(text):
    text = re.sub(r'\s*,\s*|\([^)]*\)|,\s*$', '', str(text))
    text = re.sub(r'\bsecukupnya\b', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\b- sesuaikan sesuaikan\b', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\s*,\s*', ',', str(text))
    emoticons = [':)', ':(', ':-)', ':-(', '<3','❤','🍅','🌶','🍗','🔅','👇','🐔','🍛','🌰','📓','🌱']
    for emoticon in emoticons:
        text = text.replace(emoticon, '')
    text = text.replace(':', '')

    # Eliminating some stopwords
    stop_words = set(stopwords.words('indonesian'))
    stop_words.update(['secukupnya','bumbu','bumbu halus','kating',' - sesuaikan sesuaikan','bahan kuah'])
    words = text.split()
    filtered_words = [word.lower() for word in words if word.lower() not in stop_words]

    cleaned_text = ' '.join(filtered_words)

    return cleaned_text

# %%
# Function Delete emoticons in text
def remove_emoji(text):

    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)


    no_emoji_list = emoji_pattern.sub(r'', text)

    return no_emoji_list

# %%
# Function Delete a link in a text
def remove_links(text):
    # Define the pattern for finding links
    link_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

    # Remove links from each string in the list
    no_link_list = link_pattern.sub(r'', text)

    return no_link_list

# %%
df
# Out:
#                                    Title  \
# 0                       Ayam Woku Manado
# 1               Ayam goreng tulang lunak
# 2                       Ayam cabai kawin
# 3                            Ayam Geprek
# 4                            Minyak Ayam
# ...                                  ...
# 13662                 Udang saus mentega
# 13663                 Jipang tumis udang
# 13664                  Tumis Udang Tempe
# 13665  Tumis kacang panjang terong udang
# 13666                  Siomay Udang Ayam
#
#                                              Ingredients  Loves
# 0      1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...      1
# 1      1 kg ayam (dipotong sesuai selera jangan kecil...      1
# 2      1/4 kg ayam--3 buah cabai hijau besar--7 buah ...      2
# 3      250 gr daging ayam (saya pakai fillet)--Secuku...     10
# 4      400 gr kulit ayam & lemaknya--8 siung bawang p...      4
# ...                                                  ...    ...
# ...

# %%
Loves = pd.DataFrame(df.Loves)
Loves
# Out:
#        Loves
# 0          1
# 1          1
# 2          2
# 3         10
# 4          4
# ...      ...
# 13662     46
# 13663      6
# 13664      3
# 13665     12
# 13666     28
#
# [13667 rows x 1 columns]

# %%
Ingredients = pd.DataFrame(df.Ingredients)
Ingredients
# Out:
#                                              Ingredients
# 0      1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1      1 kg ayam (dipotong sesuai selera jangan kecil...
# 2      1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3      250 gr daging ayam (saya pakai fillet)--Secuku...
# 4      400 gr kulit ayam & lemaknya--8 siung bawang p...
# ...                                                  ...
# 13662  1 kg udang segar--1 buah bawang bombay kecil--...
# 13663  500 gr jipang(saya pk 6bh jipang muda yg kecil...
# 13664  3 siung bawang merah--3 siung bawang putih--2 ...
# 13665  Stgah ikat kacang panjang,ku bli 3ribu d psr--...
# 13666  3 bh dada ayam--1/2 kg udang bersih--6 bh bawa...
#
# [13667 rows x 1 columns]

# %%
df_ingredients = pd.DataFrame(Ingredients)

# Clearing data in the 'Ingredients' column
df_ingredients['Ingredients'] = df_ingredients['Ingredients'].apply(clean_ingredients)
df_ingredients['Ingredients'] = df_ingredients['Ingredients'].apply(remove_links)
df_ingredients['Ingredients'] = df_ingredients['Ingredients'].apply(remove_emoji)
df_ingredients['Ingredients'] = df_ingredients['Ingredients'].str.split('--')

df_ingredients
# Out:
#                                              Ingredients
# 0      [1 ekor ayam kampung , 2 buah jeruk nipis, 2 s...
# 1      [1 kg ayam , 2 batang serai , 4 lembar daun je...
# 2      [1/4 kg ayam, 3 buah cabai hijau besar, 7 buah...
# 3      [250 gr daging ayam ,  gula garam, 50-100 gr t...
# 4      [400 gr kulit ayam & lemaknya, 8 siung bawang ...
# ...                                                  ...
# 13662  [1 kg udang segar, 1 buah bawang bombay kecil,...
# 13663  [500 gr jipangpotong korek api, 5 butir bawang...
# 13664  [3 siung bawang merah, 3 siung bawang putih, 2...
# 13665  [stgah ikat kacang panjangku bli 3ribu d psr, ...
# 13666  [3 bh dada ayam, 1/2 kg udang bersih, 6 bh baw...
#
# [13667 rows x 1 columns]

# %%
Title = pd.DataFrame(df.Title)
Title
# Out:
#                                    Title
# 0                       Ayam Woku Manado
# 1               Ayam goreng tulang lunak
# 2                       Ayam cabai kawin
# 3                            Ayam Geprek
# 4                            Minyak Ayam
# ...                                  ...
# 13662                 Udang saus mentega
# 13663                 Jipang tumis udang
# 13664                  Tumis Udang Tempe
# 13665  Tumis kacang panjang terong udang
# 13666                  Siomay Udang Ayam
#
# [13667 rows x 1 columns]

# %%
df_title = pd.DataFrame(Title)

# Clearing data in the 'Title' column
df_title['Title'] = df_title['Title'].apply(clean_ingredients)
df_title['Title'] = df_title['Title'].apply(remove_links)
df_title['Title'] = df_title['Title'].apply(remove_emoji)


# Menampilkan hasil
df_title
# Out:
#                            Title
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
# [13667 rows x 1 columns]

# %%
#Add the clean df_ingridients column to the data set
df = pd.DataFrame(df)
df['Ingredients'] = df_ingredients
df['Title'] = df_title
df
# Out:
#                            Title  \
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
#                                              Ingredients  Loves
# 0      [1 ekor ayam kampung , 2 buah jeruk nipis, 2 s...      1
# 1      [1 kg ayam , 2 batang serai , 4 lembar daun je...      1
# 2      [1/4 kg ayam, 3 buah cabai hijau besar, 7 buah...      2
# 3      [250 gr daging ayam ,  gula garam, 50-100 gr t...     10
# 4      [400 gr kulit ayam & lemaknya, 8 siung bawang ...      4
# ...                                                  ...    ...
# 13662  [1 kg udang segar, 1 buah bawang bombay kecil,...     46
# ...

# %%
df = pd.DataFrame(df)
df_cleaned = df.dropna()

# %%
df = pd.DataFrame(df_title)
df['Ingredients'] = df_ingredients
df['Loves'] = Loves
df
# Out:
#                            Title  \
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
#                                              Ingredients  Loves
# 0      [1 ekor ayam kampung , 2 buah jeruk nipis, 2 s...      1
# 1      [1 kg ayam , 2 batang serai , 4 lembar daun je...      1
# 2      [1/4 kg ayam, 3 buah cabai hijau besar, 7 buah...      2
# 3      [250 gr daging ayam ,  gula garam, 50-100 gr t...     10
# 4      [400 gr kulit ayam & lemaknya, 8 siung bawang ...      4
# ...                                                  ...    ...
# 13662  [1 kg udang segar, 1 buah bawang bombay kecil,...     46
# ...

# %%
# Creating a word replacement dictionary
kamus_penggantian = {
    r'\bb\b': 'bawang',
    r'\bbh\b': 'buah',
}
# Function to replace words with regex
def ganti_kata(kalimat, kamus):
    for pola, ganti_dengan in kamus.items():
        kalimat = re.sub(pola, ganti_dengan, kalimat)
    return kalimat

# %%
#Function to clean text
def clean_ingredients(text):
    text = re.sub(r'\d+|\s+|\-|\/', ' ', str(text))
    text =re.sub(r'''\d+|\s+|\-|\/|kg|gr|lembar|bahan|serbaguna|siung|ruas|jari|bungkus|buah|instan uk + campur tepung terigu|jdyg bsah. beli pasaraku beli rb
    cm|ekr|ne i cuci bersih ptng air jeruk nipis cuci lagi|ekor|ml|sdm|adonan basah|sdt|iris|sck|menggoreng|proteiin tinggi|bh|air merebus mie|kating|cuci bersih''', ' ', str(text))
    text = re.sub(r"['\[\]]", '', text)
    stop_words = set(stopwords.words('indonesian'))
    stop_words.update(['secukupnya','bumbu','bumbu halus','kating',' - sesuaikan sesuaikan','bahan kuah'])
    words = text.split()
    filtered_words = [word.lower() for word in words if word.lower() not in stop_words]
    cleaned_text = ' '.join(filtered_words)

    return cleaned_text

# %%
bahan = df['Ingredients']
judul = df['Title']

# %%
# Clearing data
bahan = bahan.apply(clean_ingredients)
judul = judul.apply(clean_ingredients)

# %%
judul=pd.DataFrame(judul)
judul
# Out:
#                            Title
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
# [13667 rows x 1 columns]

# %%
bahan = pd.DataFrame(bahan)
bahan
# Out:
#                                              Ingredients
# 0      ayam kampung , jeruk nipis, garam, kunyit, baw...
# 1      ayam , batang serai , daun jeruk, butir bawang...
# 2      ayam, cabai hijau besar, cabai merah rawit, ba...
# 3      daging ayam , gula garam, tepung ayam , lalapa...
# 4      kulit ayam & lemaknya, bawang putih cincang ka...
# ...                                                  ...
# 13662  udang segar, bawang bombay kecil, bawang putih...
# 13663  jipangpotong korek api, butir bawang merahdi ,...
# 13664  bawang merah, bawang putih, cabe rawit, tomat ...
# 13665  stgah ikat kacang panjangku bli ribu d psr, te...
# 13666  dada ayam, udang bersih, bawang putih, tepung ...
#
# [13667 rows x 1 columns]

# %%
df = pd.DataFrame(judul)
df['Ingredients'] = bahan
df['Loves'] = Loves
df
# Out:
#                            Title  \
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
#                                              Ingredients  Loves
# 0      ayam kampung , jeruk nipis, garam, kunyit, baw...      1
# 1      ayam , batang serai , daun jeruk, butir bawang...      1
# 2      ayam, cabai hijau besar, cabai merah rawit, ba...      2
# 3      daging ayam , gula garam, tepung ayam , lalapa...     10
# 4      kulit ayam & lemaknya, bawang putih cincang ka...      4
# ...                                                  ...    ...
# 13662  udang segar, bawang bombay kecil, bawang putih...     46
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Ingredients', 'Loves'], dtype='object')

# %%
df.isna().sum()
# Out:
# Title          0
# Ingredients    0
# Loves          0
# dtype: int64

# %%
pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163744 sha256=e7de9d1783e096e3b89f54e1fb75627360e4a07d92d95715033d7a9779bb6fc8
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# ...

# %% [markdown]
# TRAIN MODEL

# %%
from sklearn.model_selection import train_test_split
from surprise.model_selection import train_test_split
from surprise import Dataset, Reader, KNNBasic
import joblib

# %%
resep_df = pd.DataFrame(df)

# %%
resep_df['User'] = resep_df['User'] = range(1, len(resep_df) + 1)

# %%
resep_df
# Out:
#                            Title  \
# 0               ayam woku manado
# 1       ayam goreng tulang lunak
# 2               ayam cabai kawin
# 3                    ayam geprek
# 4                    minyak ayam
# ...                          ...
# 13662         udang saus mentega
# 13663         jipang tumis udang
# 13664          tumis udang tempe
# 13665  tumis kacang terong udang
# 13666          siomay udang ayam
#
#                                              Ingredients  Loves   User
# 0      ayam kampung , jeruk nipis, garam, kunyit, baw...      1      1
# 1      ayam , batang serai , daun jeruk, butir bawang...      1      2
# 2      ayam, cabai hijau besar, cabai merah rawit, ba...      2      3
# 3      daging ayam , gula garam, tepung ayam , lalapa...     10      4
# 4      kulit ayam & lemaknya, bawang putih cincang ka...      4      5
# ...                                                  ...    ...    ...
# ...

# %%
resep_df.to_csv('dataset_daily.csv', index=False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['User']
  ys = series['Loves']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = resep_df.sort_values('User', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('User')
_ = plt.ylabel('Loves')

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise import accuracy

# %%
reader = Reader(rating_scale=(0, 1000))
data = Dataset.load_from_df(resep_df[['User','Title','Loves']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
model = KNNBasic(sim_options={'user_based': True})

# %%
model.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
from matplotlib import pyplot as plt
resep_df.plot(kind='scatter', x='Loves', y='User', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# USING KNNBasic

# %%
reader = Reader(rating_scale=(0, 500))
data = Dataset.load_from_df(resep_df[['User','Title','Loves']], reader)

# %%
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
model = KNNBasic(sim_options={'user_based': True})

# %%
model.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
joblib.dump(model, 'daily_recommendation_model.joblib')
# Out:
# ['daily_recommendation_model.joblib']

# %%
loaded_model = joblib.load('/content/daily_recommendation_model.joblib')

# %%
predictions = loaded_model.test(testset)

# %% [markdown]
# Test Accuracy KNNBasic

# %%
from surprise import accuracy

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 27.8763
# 27.876341931362465

# %%
from flask import Flask, request, jsonify
import joblib
import pandas as pd
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
import os

app = Flask(__name__)

# # Load the recommendation model
# model_filename = 'daily_recommendation_modeTest.joblib'
# script_dir = os.path.dirname(os.path.abspath(__file__))
# model_path = os.path.join(script_dir, model_filename)
loaded_model = joblib.load('/content/daily_recommendation_model.joblib')

# Assuming you have a DataFrame named 'resep_df' with the necessary columns
reader = Reader(rating_scale=(0, 1000))
data = Dataset.load_from_df(resep_df[['User', 'Title', 'Loves']], reader)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

@app.route('/predict', methods=['POST'])
def predict():
    try:
        # Ambil data input dari JSON
        data = request.get_json()
        # Ubah data ke format yang dapat digunakan oleh model
        user_input = int(data['user'])
        title_input = data['title']
        # Lakukan prediksi
        prediction = loaded_model.predict(user_input, title_input)
        # Ubah hasil prediksi ke bentuk JSON
        result = {'prediction': prediction.est}
        return jsonify(result)
    except Exception as e:
        return jsonify({'error': str(e)})

if __name__ == '__main__':
    # Ganti host dan port sesuai kebutuhan Anda
    app.run(host='0.0.0.0', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit

# %% [markdown]
# CROSS VALIDATE KNNBasic

# %%
from surprise.model_selection import cross_validate

# %%
cross_val_results = cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    27.0761 18.7014 21.0805 21.0384 19.8640 21.5521 2.8975
# Fit time          2.06    2.51    2.48    2.31    2.06    2.28    0.19
# Test time         0.02    0.04    0.03    0.03    0.02    0.03    0.01

# %%
print('Average RMSE:', sum(cross_val_results['test_rmse']) / len(cross_val_results['test_rmse']))
# Out:
# Average RMSE: 21.55209607992573

# %% [markdown]
# USING SVD

# %%
from surprise import Dataset, Reader
from surprise.model_selection import train_test_split
from surprise import SVD
from surprise import accuracy

# %%
reader = Reader(rating_scale=(0, 1000))
data = Dataset.load_from_df(resep_df[['User', 'Title', 'Loves']], reader)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# %%
svd_model = SVD(n_epochs=100, random_state=42)  # Atur n_epochs sesuai kebutuhan
svd_model.fit(trainset)

# %%
predictions = svd_model.test(testset)

# %% [markdown]
# TEST ACCURACY SVD

# %%
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 27.7579
# RMSE: 27.75794966873815

# %%
import pickle
pickle.dump(svd_model, open("svd_model.pkl", 'wb'))

# %%
joblib.dump(svd_model, 'svd_model.joblib')
# Out:
# ['svd_model.joblib']

# %% [markdown]
# HASIL DARI MODEL SVD

# %%
user_id = '100'
recipes_to_recommend = []

for item_id in resep_df['Title'].unique():
    if not trainset.knows_user(user_id) or not trainset.knows_item(item_id):
        recipes_to_recommend.append((item_id, svd_model.predict(user_id, item_id).est))

# %%
recipes_to_recommend.sort(key=lambda x: x[1], reverse=True)

# %%
print(f"Resep Harian yang Direkomendasikan untuk Pengguna {user_id}:")
for recipe, predicted_rating in recipes_to_recommend[:5]:
    print(f"{recipe}")
# Out:
# Resep Harian yang Direkomendasikan untuk Pengguna 100:
# chilli tuna puff kilat super yummy
# perkedel simple
# sop iga sapi enaaak bangeet
# nasi goreng kambing...ala kebon sirih
# nasi kebuli magicom #kitaberbagi

# %%
import pickle

with open('svd_model.pkl', 'rb') as pickle_file:
  new_data = pickle.load(pickle_file)

print(new_data)
